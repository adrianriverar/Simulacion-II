# %%
## Ejercicio 31 marzo 2023

import numpy as np
from random import random

def f(x):
  return np.sqrt(np.arctan(x))

r = np.array([random()])
n = 1000

for i in range(n - 1):
  r = np.append(r, random())

theta = sum(f(r)) / n
print(theta)
# Out:
# 0.6366051492511811
